# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabela0929/Exercises-SyS-Isabela-Londono-Castaneda/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Ejemplo1SyS2021.ipynb - Isabela Londoño Castañeda**

# %% [markdown]
# Ejercicio:
# Después de acondicionar las señales ilustradas en el presente cuaderno, simule un proceso de discretización con  Fs≥2Fo.  Dibuje el resultado de la señal discretizada utilizando la función stem.
#
# Consultar el funcionamiento de los métodos cdist y argmin.
#
# Realice una función mediante el ambiente def que permita realizar los procesos de discretización y cuantización (usando cdist y argmin) en cascada para un conversor análogo-digital de 3 bits con entrada análoga de 0 a 10 [v]. Presente las gráficas de la señal original, señal con cero y pendiente, señal discretizada, y señal digital.

# %% [markdown]
# - Se ilustra nuevamente el proceso de acondicionamiento cero y pendiente utilizando una función seno:
#
# $$x[t_k] = A \sin[w_o t + \phi]$$
#
# $$x[t_k] = A \sin[2 \pi F_o t] = A \sin[2 \pi t / T_o ]$$

# %%
import numpy as np
import matplotlib.pyplot as plt
K = 500 # número de muestras
T_o = 1/60 # periodo función sin
A = 120 # amplitud
ti = 0 #tiempo inicial
tf = T_o #tiempo final
tv = np.linspace(ti,tf,num=K) #vector de datos en tiempo
xv = A * np.sin(2*np.pi*tv/T_o) #vector de amplitud

plt.plot(tv,xv, "y.")
plt.xlabel('tiempo [s]')
plt.ylabel('$A\sin[\omega t_k]$')
plt.show()

# %%
#parte 1 del ejercicio
Fo = 60
Fs =50*Fo
Ts = 1/Fs
To = 1/Fo
ti = 0 # tiempo incial referencia [s]
tf = To # tiempo final  [s]

tw = np.arange(ti,tf,Ts)
se = 120*np.cos(2*np.pi*Fo*tw)
print(tw)
print(tw.shape)
# tiempo muestreo se define según el rango de trabajo en segundos y la cantidad de muestras
print(se.shape)
plt.stem(tw, se)
# Out:
# [0.         0.00033333 0.00066667 0.001      0.00133333 0.00166667
#  0.002      0.00233333 0.00266667 0.003      0.00333333 0.00366667
#  0.004      0.00433333 0.00466667 0.005      0.00533333 0.00566667
#  0.006      0.00633333 0.00666667 0.007      0.00733333 0.00766667
#  0.008      0.00833333 0.00866667 0.009      0.00933333 0.00966667
#  0.01       0.01033333 0.01066667 0.011      0.01133333 0.01166667
#  0.012      0.01233333 0.01266667 0.013      0.01333333 0.01366667
#  0.014      0.01433333 0.01466667 0.015      0.01533333 0.01566667
#  0.016      0.01633333]
# (50,)
# (50,)
# <StemContainer object of 3 artists>

# %%
#Parte 2 del ejercicio
Fo = 60
Fs = 50*Fo
A = 120
Ts = 1/Fs
To = 1/Fo
ti = 0 # tiempo incial referencia [s]
tf = To # tiempo final  [s]
it = np.arange(ti,tf,Ts)
se = A*np.cos(2*np.pi*Fo*tw)

ycs = my_ceropen(se, ymin=0,ymax=10) #cero y pendiente

nbits = 3 #número de bits y vector de cuantización
rmin = 0
rmax = 10

ve = np.linspace(rmin,rmax,2**nbits)
d.shape

ind = np.argmin(d,axis=1)
ind

def my_cuantizador(yn, vq) :
 Ne=vq.shape[0]
 dn = cdist(yn.reshape(-1,1),vq.reshape(-1,1))
 ind = np.argmin(dn)
 return vq[ind]

for i in range(ycs.shape[0]):
   if i==0:
     yq = my_cuantizador(ycs[i],ve)
   else:
     yq = np.append(yq,my_cuantizador(ycs[i],ve))


plt.plot(it,ycs,c='r', label='ycs')#cs continua

plt.stem(it,ycs, label='ycs_dis')#cs discreta

#estados de cuantización

for v in ve:
  plt.plot(it,v*np.ones(len(it)))

# graficar señal Digital (discreta + cuantizada)

plt.plot(it,yq,c='y',marker='o',label='ydig', linewidth=2)

plt.legend()
plt.grid()
plt.xlabel('t')
plt.ylabel('Amplitud')
plt.show()
